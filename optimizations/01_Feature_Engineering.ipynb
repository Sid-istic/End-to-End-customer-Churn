# %% [markdown]
# <a href="https://colab.research.google.com/github/Sid-istic/End-to-End-customer-Churn/blob/main/optimizations/01_Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Adding a new feature to dataset

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder , LabelEncoder
import pickle

# %%
churn = pd.read_csv('churn.csv')

# %%
#how many services a customer is using
services = ['PhoneService', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
            'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

churn['NumServices'] = churn[services].apply(lambda row: sum(row == 'Yes'), axis=1)

# %%
churn = churn.drop('customerID' , axis = 1)
churn.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# ...

# %% [markdown]
# **OneHotEncoding**

# %%
churn_encoded = pd.get_dummies(churn, drop_first=True)

# %%
object_colms = churn.select_dtypes(include='object').columns
object_colms
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
encoders = {}

for col in object_colms:
    encoders[col] = OneHotEncoder(sparse_output = False)
    churn[col] = encoders[col].fit_transform(churn[[col]])
with open('onehot_encoders.pkl' , 'wb') as f:
    pickle.dump(encoders , f)

# %%
encoders
# Out:
# {'gender': OneHotEncoder(sparse_output=False),
#  'Partner': OneHotEncoder(sparse_output=False),
#  'Dependents': OneHotEncoder(sparse_output=False),
#  'PhoneService': OneHotEncoder(sparse_output=False),
#  'MultipleLines': OneHotEncoder(sparse_output=False),
#  'InternetService': OneHotEncoder(sparse_output=False),
#  'OnlineSecurity': OneHotEncoder(sparse_output=False),
#  'OnlineBackup': OneHotEncoder(sparse_output=False),
#  'DeviceProtection': OneHotEncoder(sparse_output=False),
#  'TechSupport': OneHotEncoder(sparse_output=False),
#  'StreamingTV': OneHotEncoder(sparse_output=False),
#  'StreamingMovies': OneHotEncoder(sparse_output=False),
#  'Contract': OneHotEncoder(sparse_output=False),
#  'PaperlessBilling': OneHotEncoder(sparse_output=False),
#  'PaymentMethod': OneHotEncoder(sparse_output=False),
#  'TotalCharges': OneHotEncoder(sparse_output=False),
#  'Churn': OneHotEncoder(sparse_output=False)}

# %%
churn.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0     1.0              0      0.0         1.0       1           1.0
# 1     0.0              0      1.0         1.0      34           0.0
# 2     0.0              0      1.0         1.0       2           0.0
# 3     0.0              0      1.0         1.0      45           1.0
# 4     1.0              0      1.0         1.0       2           0.0
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  ...  \
# 0            0.0              1.0             1.0           0.0  ...
# 1            1.0              1.0             0.0           1.0  ...
# 2            1.0              1.0             0.0           0.0  ...
# 3            0.0              1.0             0.0           1.0  ...
# 4            1.0              0.0             1.0           1.0  ...
#
#    TechSupport  StreamingTV  StreamingMovies  Contract  PaperlessBilling  \
# ...

# %%
churn.to_csv('churn_processed.csv' , index = False)
